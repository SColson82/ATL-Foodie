# %%
import json
import pandas as pd
import numpy as np

# %%
data_file = open("C:/Users/Sharon/datacode/Class-Projects/ATL-Foodie-heck yea/SourceData/yelp_academic_dataset_review.json", encoding='utf8') 
data = []
for line in data_file:
    data.append(json.loads(line))
df = pd.DataFrame(data)
data_file.close()

# %%
df
# Out:
#                    business_id                     name               address  \
# 0       6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom          921 Pearl St
# 1       tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX   7000 NE Airport Way
# 2       bvN78flM8NLprQ1a1y5dRg           The Reclaimory    4720 Hawthorne Ave
# 3       oaepsyvc0J17qwi8cfrOWg              Great Clips    2566 Enterprise Rd
# 4       PE9uqAjdw0E4-8mjGl3wVA        Crossfit Terminus   1046 Memorial Dr SE
# ...                        ...                      ...                   ...
# 160580  D2mHoIDXx9N8mS1pGoKV9Q       Eleven Oaks Realty
# 160581  bQX-kwVTyZgcdZGEPzce6Q             Webb's Honey    21777 State Rd 520
# 160582  wvFZ06nmPmQ2-IVoPqVYLA    Painting with a Twist  2164 S Chickasaw Trl
# 160583  GB75wPibj3IjNauaoCxyGA              Havana Cafe        910 NW 14th St
# 160584  ngmLL5Y5OT-bYHKU0kKrYA              Zora Grille   1370 E Altamonte Dr
#
# ...

# %%
df.isnull().sum()
# Out:
# review_id      0
# user_id        0
# business_id    0
# stars          0
# useful         0
# funny          0
# cool           0
# text           0
# date           0
# dtype: int64

# %%
atl_restaurant_df=pd.read_csv("C:/Users/Sharon/datacode/Class-Projects/ATL-Foodie-heck yea/Resources/yelp_atl_restaurants_csv.csv")
atl_restaurant_df.head()
# Out:
#    Unnamed: 0             business_id                            name  \
# 0          62  z8-_6l5EhX5NuPfWzJYQMA                     Great Wraps
# 1          86  Q2vefh0tGhtCGQDK1FI7cw                   Piece of Cake
# 2         105  TbZDLpBOl-EbO2LfMySrEg          First China Restaurant
# 3         147  bP6goJODwRnM3AVy45Kn9w  Papi's Cuban & Caribbean Grill
# 4         165  xSLdQjPgMhBrNIEtUgdWUA                  Colossus Pizza
#
#                     address     city state  postal_code   latitude  longitude  \
# 0      3393 Peachtree Rd NE  Atlanta    GA        30326  33.846335 -84.363578
# 1        3215 Roswell Rd NE  Atlanta    GA        30305  33.842875 -84.378539
# 2        5295 Buford Hwy NE  Atlanta    GA        30340  33.896641 -84.280918
# 3  216 Ponce De Leon Ave NE  Atlanta    GA        30308  33.772758 -84.380375
# 4       4369 Hugh Howell Rd   Tucker    GA        30084  33.850775 -84.209299
#
#    stars  review_count  is_open  \
# 0    3.0            11        1
# ...

# %%
atl_restaurant_review_df=pd.merge(atl_restaurant_df,df, on="business_id", how ="left")
atl_restaurant_review_df
# Out:
#         Unnamed: 0             business_id                  name  \
# 0               62  z8-_6l5EhX5NuPfWzJYQMA           Great Wraps
# 1               62  z8-_6l5EhX5NuPfWzJYQMA           Great Wraps
# 2               62  z8-_6l5EhX5NuPfWzJYQMA           Great Wraps
# 3               62  z8-_6l5EhX5NuPfWzJYQMA           Great Wraps
# 4               62  z8-_6l5EhX5NuPfWzJYQMA           Great Wraps
# ...            ...                     ...                   ...
# 477664      160575  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina
# 477665      160575  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina
# 477666      160575  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina
# 477667      160575  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina
# 477668      160575  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina
#
#                      address     city state  postal_code   latitude  \
# 0       3393 Peachtree Rd NE  Atlanta    GA        30326  33.846335
# ...

# %%
clean_atl_restaurant_review_df = atl_restaurant_review_df.drop(['Unnamed: 0'], axis=1).dropna(how='any')
clean_atl_restaurant_review_df
# Out:
#                    business_id                  name               address  \
# 0       z8-_6l5EhX5NuPfWzJYQMA           Great Wraps  3393 Peachtree Rd NE
# 1       z8-_6l5EhX5NuPfWzJYQMA           Great Wraps  3393 Peachtree Rd NE
# 2       z8-_6l5EhX5NuPfWzJYQMA           Great Wraps  3393 Peachtree Rd NE
# 3       z8-_6l5EhX5NuPfWzJYQMA           Great Wraps  3393 Peachtree Rd NE
# 4       z8-_6l5EhX5NuPfWzJYQMA           Great Wraps  3393 Peachtree Rd NE
# ...                        ...                   ...                   ...
# 477664  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina   1958 Piedmont Rd NE
# 477665  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina   1958 Piedmont Rd NE
# 477666  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina   1958 Piedmont Rd NE
# 477667  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina   1958 Piedmont Rd NE
# 477668  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina   1958 Piedmont Rd NE
#
#            city state  postal_code   latitude  longitude  stars_x  \
# ...

# %%
clean_atl_restaurant_review_df.head(2)
# Out:
#               business_id         name               address     city state  \
# 0  z8-_6l5EhX5NuPfWzJYQMA  Great Wraps  3393 Peachtree Rd NE  Atlanta    GA
# 1  z8-_6l5EhX5NuPfWzJYQMA  Great Wraps  3393 Peachtree Rd NE  Atlanta    GA
#
#    postal_code   latitude  longitude  stars_x  review_count  ...  \
# 0        30326  33.846335 -84.363578      3.0            11  ...
# 1        30326  33.846335 -84.363578      3.0            11  ...
#
#                                           categories  \
# 0  Food, Restaurants, Cheesesteaks, Sandwiches, J...
# 1  Food, Restaurants, Cheesesteaks, Sandwiches, J...
#
#                                                hours               review_id  \
# 0  {'Monday': '7:0-21:0', 'Tuesday': '7:0-21:0', ...  KM7ZEiGlyX63IFpOIjqrSA
# 1  {'Monday': '7:0-21:0', 'Tuesday': '7:0-21:0', ...  dKIxCfc59WdoBIIDOJ_yKg
#
#                   user_id stars_y useful  funny  cool  \
# 0  7PiRdxYF-Uvzn2fHqdtU1Q     5.0      0      0     0
# ...

# %%
clean_atl_restaurant_review_df.isnull().sum()
# Out:
# business_id     0
# name            0
# address         0
# city            0
# state           0
# postal_code     0
# latitude        0
# longitude       0
# stars_x         0
# review_count    0
# is_open         0
# attributes      0
# categories      0
# hours           0
# review_id       0
# user_id         0
# stars_y         0
# useful          0
# funny           0
# cool            0
# text            0
# date            0
# dtype: int64

# %%
clean_atl_restaurant_review_df.drop(clean_atl_restaurant_review_df[clean_atl_restaurant_review_df['is_open']==0].index,inplace=True)
clean_atl_restaurant_review_df
# Out:
#                    business_id                  name               address  \
# 0       z8-_6l5EhX5NuPfWzJYQMA           Great Wraps  3393 Peachtree Rd NE
# 1       z8-_6l5EhX5NuPfWzJYQMA           Great Wraps  3393 Peachtree Rd NE
# 2       z8-_6l5EhX5NuPfWzJYQMA           Great Wraps  3393 Peachtree Rd NE
# 3       z8-_6l5EhX5NuPfWzJYQMA           Great Wraps  3393 Peachtree Rd NE
# 4       z8-_6l5EhX5NuPfWzJYQMA           Great Wraps  3393 Peachtree Rd NE
# ...                        ...                   ...                   ...
# 477664  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina   1958 Piedmont Rd NE
# 477665  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina   1958 Piedmont Rd NE
# 477666  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina   1958 Piedmont Rd NE
# 477667  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina   1958 Piedmont Rd NE
# 477668  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina   1958 Piedmont Rd NE
#
#            city state  postal_code   latitude  longitude  stars_x  \
# ...

# %%
clean_atl_restaurant_review_df.describe()
# Out:
#          postal_code       latitude      longitude        stars_x  \
# count  465047.000000  465047.000000  465047.000000  465047.000000
# mean    30293.292964      33.810447     -84.348436       3.757202
# std        80.314952       0.051095       0.038895       0.535368
# min     30002.000000      33.639574     -84.457466       1.000000
# 25%     30307.000000      33.772200     -84.379998       3.500000
# 50%     30309.000000      33.787963     -84.362742       4.000000
# 75%     30326.000000      33.846614     -84.327221       4.000000
# max     30360.000000      33.949866     -84.200206       5.000000
#
#         review_count        is_open        stars_y         useful  \
# count  465047.000000  465047.000000  465047.000000  465047.000000
# mean      563.883014       0.793133       3.754257       0.956422
# std       679.039530       0.405060       1.339280       2.805317
# min         5.000000       0.000000       1.000000       0.000000
# ...

# %%
clean_atl_restaurant_review_df2=clean_atl_restaurant_review_df.rename(columns={'stars_x':'stars(avg)','stars_y':'stars(review)'}).drop(['is_open'],axis=1)
clean_atl_restaurant_review_df2
# Out:
#                    business_id                  name               address  \
# 0       z8-_6l5EhX5NuPfWzJYQMA           Great Wraps  3393 Peachtree Rd NE
# 1       z8-_6l5EhX5NuPfWzJYQMA           Great Wraps  3393 Peachtree Rd NE
# 2       z8-_6l5EhX5NuPfWzJYQMA           Great Wraps  3393 Peachtree Rd NE
# 3       z8-_6l5EhX5NuPfWzJYQMA           Great Wraps  3393 Peachtree Rd NE
# 4       z8-_6l5EhX5NuPfWzJYQMA           Great Wraps  3393 Peachtree Rd NE
# ...                        ...                   ...                   ...
# 477664  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina   1958 Piedmont Rd NE
# 477665  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina   1958 Piedmont Rd NE
# 477666  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina   1958 Piedmont Rd NE
# 477667  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina   1958 Piedmont Rd NE
# 477668  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina   1958 Piedmont Rd NE
#
# ...

# %%
final_atl_restaurant_review_df=clean_atl_restaurant_review_df2.sample(n=40000)
final_atl_restaurant_review_df
# Out:
#                    business_id                           name  \
# 388551  dTsp-JNNA7u5F9WtxVBEug                    Bistro Niko
# 332247  LcBV4SR2IYK970f2X-1flA         Farm Burger - Dunwoody
# 450177  4w3OTSAnGkpMUBellQKcsQ                     MetroFresh
# 317217  xI56hTOOHsQfk-DZviOrxQ           The Original El Taco
# 120950  eG-UO83g_5zDk70FIJbm2w     South City Kitchen Midtown
# ...                        ...                            ...
# 102211  rttvJkm9fTHmVQrsD6EA5A                   Bo Bo Garden
# 389757  f2tTzO54v9FNUZaGbIXJFQ            Varasano's Pizzeria
# 245932  vdQLCK1Y--vI2Oq7Nfm0nw  The Big Ketch Saltwater Grill
# 137194  YIPzFF0CVgMCcly67VHgjw                        bartaco
# 6741    MlXsuBBd9UwgBkQzrGDJqA                  LanZhou Ramen
#
#                               address       city state  postal_code  \
# 388551           3344 Peachtree Rd NE    Atlanta    GA        30326
# 332247     4514B Chamblee Dunwoody Rd   Dunwoody    GA        30338
# ...

# %%
final_atl_restaurant_review_df.to_json("yelp_atl_restaurant_reviews_json.json")

# %%
final_atl_restaurant_review_df.to_csv("yelp_atl_restaurant_reviews_csv.csv")
