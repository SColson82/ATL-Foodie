# %%
import json
import pandas as pd

# %%
data_file = open("yelp_academic_dataset_checkin.json", encoding='utf8')
data = []
for line in data_file:
    data.append(json.loads(line))
df = pd.DataFrame(data)
data_file.close()

# %%
df
# Out:
#                    business_id  \
# 0       --0r8K_AQ4FZfLsX3ZYRDA
# 1       --0zrn43LEaB4jUWTQH_Bg
# 2       --164t1nclzzmca7eDiJMw
# 3       --2aF9NhXnNVpDV0KS3xBQ
# 4       --2mEJ63SC_8_08_jGgVIg
# ...                        ...
# 138871  zzoUa7lyeM-qKPKFYSrAhg
# 138872  zzpmoTVq4yn86U7ArHyFBQ
# 138873  zzqq8J7Pibxod1YcknlkWA
# 138874  zzwK-TJsCJX5wZrdtKemPg
# 138875  zzzKmD9Mj6WtJwJUhA_1dg
#
#                                                      date
# 0                                     2017-09-03 17:13:59
# 1       2010-10-08 22:21:20, 2010-11-01 21:29:14, 2010...
# 2       2010-02-26 02:06:53, 2010-02-27 08:00:09, 2010...
# 3       2014-11-03 16:35:35, 2015-01-30 18:16:03, 2015...
# 4       2010-12-15 17:10:46, 2013-12-28 00:27:54, 2015...
# ...                                                   ...
# 138871  2012-10-12 17:11:06, 2012-10-22 23:38:12, 2012...
# 138872  2020-07-18 18:33:18, 2020-07-18 20:13:49, 2020...
# ...

# %%
df.isnull().sum()
# Out:
# business_id    0
# date           0
# dtype: int64

# %%
atl_restaurant_df=pd.read_csv("yelp_atl_restaurants_csv.csv")
atl_restaurant_df.head()
# Out:
#    Unnamed: 0             business_id                            name  \
# 0          62  z8-_6l5EhX5NuPfWzJYQMA                     Great Wraps
# 1          86  Q2vefh0tGhtCGQDK1FI7cw                   Piece of Cake
# 2         105  TbZDLpBOl-EbO2LfMySrEg          First China Restaurant
# 3         147  bP6goJODwRnM3AVy45Kn9w  Papi's Cuban & Caribbean Grill
# 4         165  xSLdQjPgMhBrNIEtUgdWUA                  Colossus Pizza
#
#                     address     city state  postal_code   latitude  longitude  \
# 0      3393 Peachtree Rd NE  Atlanta    GA        30326  33.846335 -84.363578
# 1        3215 Roswell Rd NE  Atlanta    GA        30305  33.842875 -84.378539
# 2        5295 Buford Hwy NE  Atlanta    GA        30340  33.896641 -84.280918
# 3  216 Ponce De Leon Ave NE  Atlanta    GA        30308  33.772758 -84.380375
# 4       4369 Hugh Howell Rd   Tucker    GA        30084  33.850775 -84.209299
#
#    stars  review_count  is_open  \
# 0    3.0            11        1
# ...

# %%
atl_restaurant_checkin_df=pd.merge(atl_restaurant_df,df, on="business_id", how ="left")
atl_restaurant_checkin_df
# Out:
#       Unnamed: 0             business_id                            name  \
# 0             62  z8-_6l5EhX5NuPfWzJYQMA                     Great Wraps
# 1             86  Q2vefh0tGhtCGQDK1FI7cw                   Piece of Cake
# 2            105  TbZDLpBOl-EbO2LfMySrEg          First China Restaurant
# 3            147  bP6goJODwRnM3AVy45Kn9w  Papi's Cuban & Caribbean Grill
# 4            165  xSLdQjPgMhBrNIEtUgdWUA                  Colossus Pizza
# ...          ...                     ...                             ...
# 3147      160375  fyBLsgCl04kzDyDvvntsig                    Marco's Pita
# 3148      160390  N7luSQX9HJIYJzIdqzIEng           Vickery's Bar & Grill
# 3149      160499  P6VbBg5uNhAaANcpwm2cVQ           Moe's Southwest Grill
# 3150      160522  OF1RGkYOeT2xxoi_Xnec7w                Emeril's Atlanta
# 3151      160575  uXdQkuEtvLAzfc3MsO-sTQ            Mama's Cocina Latina
#
#                         address     city state  postal_code   latitude  \
# ...

# %%
atl_restaurant_checkin_df.head(2)
# Out:
#    Unnamed: 0             business_id           name               address  \
# 0          62  z8-_6l5EhX5NuPfWzJYQMA    Great Wraps  3393 Peachtree Rd NE
# 1          86  Q2vefh0tGhtCGQDK1FI7cw  Piece of Cake    3215 Roswell Rd NE
#
#       city state  postal_code   latitude  longitude  stars  review_count  \
# 0  Atlanta    GA        30326  33.846335 -84.363578    3.0            11
# 1  Atlanta    GA        30305  33.842875 -84.378539    4.0           231
#
#    is_open                                         attributes  \
# 0        1  {'RestaurantsGoodForGroups': 'False', 'GoodFor...
# 1        1  {'BikeParking': 'True', 'BusinessParking': "{'...
#
#                                           categories  \
# 0  Food, Restaurants, Cheesesteaks, Sandwiches, J...
# 1  Restaurants, Patisserie/Cake Shop, Desserts, F...
#
#                                                hours  \
# 0  {'Monday': '7:0-21:0', 'Tuesday': '7:0-21:0', ...
# ...

# %%
atl_restaurant_checkin_df.to_json("yelp_atl_restaurant_checkins_json.json")

# %%
atl_restaurant_checkin_df.to_csv("yelp_atl_restaurant_checkins_csv.csv", index=False)
