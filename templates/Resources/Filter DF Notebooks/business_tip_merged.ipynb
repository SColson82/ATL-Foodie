# %%
import json
import pandas as pd

# %%
data_file = open("yelp_academic_dataset_tip.json", encoding='utf8')
data = []
for line in data_file:
    data.append(json.loads(line))
df = pd.DataFrame(data)
data_file.close()

# %%
df
# Out:
#                         user_id             business_id  \
# 0        WCjg0jdHXMlwbqS9tZUx8Q  ENwBByjpoa5Gg7tKgxqwLg
# 1        42-Z02y9bABShAGZhuSzrQ  jKO4Og6ucdX2-YCTKQVYjg
# 2        5u7E3LYp_3eB8dLuUBazXQ  9Bto7mky640ocgezVKSfVg
# 3        wDWoMG5N9oI4DJ-p7z8EBg  XWFjKtRGZ9khRGtGg2ZvaA
# 4        JmuFlorjjRshHTKzTwNtgg  mkrx0VhSMU3p3uhyJGCoWA
# ...                         ...                     ...
# 1162114  OAf2rC_Btse6aRc9LCyApw  BYKjzEUv6RksSVm5yqGPDA
# 1162115  bI5zqhhpU4SlW-5BN6M1uw  C2kDo2CFGP_0073dgMmZNw
# 1162116  vDMl9JwvkRNRVt_rjpQdZg  4CxF8c3MB7VAdY8zFb2cZQ
# 1162117  iCc7UVah7zE1UwYPP3FcTg  IEHoGw0V5Lbdf4TJU58K0Q
# 1162118  e9x-ZsbUPTVX3Xv_L9vSaw  Mt-6e5pSAft1f3sA8tTOsQ
#
#                                                       text  \
# 0                                     Carne asada chips...
# 1        Best happy hour from 3pm to 6pm! $1 off martin...
# 2        Nice people, skilled staff, clean location - b...
# ...

# %%
df.isnull().sum()
# Out:
# user_id             0
# business_id         0
# text                0
# date                0
# compliment_count    0
# dtype: int64

# %%
atl_restaurant_df=pd.read_csv("Resources/yelp_atl_restaurants_csv.csv")
atl_restaurant_df.head()
# Out:
#    Unnamed: 0             business_id                            name  \
# 0          62  z8-_6l5EhX5NuPfWzJYQMA                     Great Wraps
# 1          86  Q2vefh0tGhtCGQDK1FI7cw                   Piece of Cake
# 2         105  TbZDLpBOl-EbO2LfMySrEg          First China Restaurant
# 3         147  bP6goJODwRnM3AVy45Kn9w  Papi's Cuban & Caribbean Grill
# 4         165  xSLdQjPgMhBrNIEtUgdWUA                  Colossus Pizza
#
#                     address     city state  postal_code   latitude  longitude  \
# 0      3393 Peachtree Rd NE  Atlanta    GA        30326  33.846335 -84.363578
# 1        3215 Roswell Rd NE  Atlanta    GA        30305  33.842875 -84.378539
# 2        5295 Buford Hwy NE  Atlanta    GA        30340  33.896641 -84.280918
# 3  216 Ponce De Leon Ave NE  Atlanta    GA        30308  33.772758 -84.380375
# 4       4369 Hugh Howell Rd   Tucker    GA        30084  33.850775 -84.209299
#
#    stars  review_count  is_open  \
# 0    3.0            11        1
# ...

# %%
atl_restaurant_df.drop(['Unnamed: 0'], axis=1)
# Out:
#                  business_id                            name  \
# 0     z8-_6l5EhX5NuPfWzJYQMA                     Great Wraps
# 1     Q2vefh0tGhtCGQDK1FI7cw                   Piece of Cake
# 2     TbZDLpBOl-EbO2LfMySrEg          First China Restaurant
# 3     bP6goJODwRnM3AVy45Kn9w  Papi's Cuban & Caribbean Grill
# 4     xSLdQjPgMhBrNIEtUgdWUA                  Colossus Pizza
# ...                      ...                             ...
# 3147  fyBLsgCl04kzDyDvvntsig                    Marco's Pita
# 3148  N7luSQX9HJIYJzIdqzIEng           Vickery's Bar & Grill
# 3149  P6VbBg5uNhAaANcpwm2cVQ           Moe's Southwest Grill
# 3150  OF1RGkYOeT2xxoi_Xnec7w                Emeril's Atlanta
# 3151  uXdQkuEtvLAzfc3MsO-sTQ            Mama's Cocina Latina
#
#                         address     city state  postal_code   latitude  \
# 0          3393 Peachtree Rd NE  Atlanta    GA        30326  33.846335
# 1            3215 Roswell Rd NE  Atlanta    GA        30305  33.842875
# ...

# %%
atl_restaurant_tip_df=pd.merge(atl_restaurant_df,df, on="business_id", how ="left")
atl_restaurant_tip_df
# Out:
#        Unnamed: 0             business_id                  name  \
# 0              62  z8-_6l5EhX5NuPfWzJYQMA           Great Wraps
# 1              86  Q2vefh0tGhtCGQDK1FI7cw         Piece of Cake
# 2              86  Q2vefh0tGhtCGQDK1FI7cw         Piece of Cake
# 3              86  Q2vefh0tGhtCGQDK1FI7cw         Piece of Cake
# 4              86  Q2vefh0tGhtCGQDK1FI7cw         Piece of Cake
# ...           ...                     ...                   ...
# 68308      160575  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina
# 68309      160575  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina
# 68310      160575  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina
# 68311      160575  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina
# 68312      160575  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina
#
#                     address     city state  postal_code   latitude  longitude  \
# 0      3393 Peachtree Rd NE  Atlanta    GA        30326  33.846335 -84.363578
# ...

# %%
# atl_restaurant_tip_df = atl_restaurant_tip_df.drop(['Unnamed: 0'], axis=1)
atl_restaurant_tip_df.head(2)
# Out:
#               business_id           name               address     city state  \
# 0  z8-_6l5EhX5NuPfWzJYQMA    Great Wraps  3393 Peachtree Rd NE  Atlanta    GA
# 1  Q2vefh0tGhtCGQDK1FI7cw  Piece of Cake    3215 Roswell Rd NE  Atlanta    GA
#
#    postal_code   latitude  longitude  stars  review_count  is_open  \
# 0        30326  33.846335 -84.363578    3.0            11        1
# 1        30305  33.842875 -84.378539    4.0           231        1
#
#                                           attributes  \
# 0  {'RestaurantsGoodForGroups': 'False', 'GoodFor...
# 1  {'BikeParking': 'True', 'BusinessParking': "{'...
#
#                                           categories  \
# 0  Food, Restaurants, Cheesesteaks, Sandwiches, J...
# 1  Restaurants, Patisserie/Cake Shop, Desserts, F...
#
#                                                hours                 user_id  \
# 0  {'Monday': '7:0-21:0', 'Tuesday': '7:0-21:0', ...                     NaN
# ...

# %%
atl_restaurant_tip_df.to_json("yelp_atl_restaurant_tips_json.json")

# %%
atl_restaurant_tip_df.to_csv("yelp_atl_restaurant_tips_csv.csv", index=False)
