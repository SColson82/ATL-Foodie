# %%
import pandas as pd

# %%
df = pd.read_csv("../yelp_atl_restaurants_csv.csv")
df1 = df.drop(['Unnamed: 0'], axis=1)
df1
# Out:
#                  business_id                            name  \
# 0     z8-_6l5EhX5NuPfWzJYQMA                     Great Wraps
# 1     Q2vefh0tGhtCGQDK1FI7cw                   Piece of Cake
# 2     TbZDLpBOl-EbO2LfMySrEg          First China Restaurant
# 3     bP6goJODwRnM3AVy45Kn9w  Papi's Cuban & Caribbean Grill
# 4     yCeENvVAGQQ0PeeWU0Pl2g           Nature's Table Bistro
# ...                      ...                             ...
# 4835  fyBLsgCl04kzDyDvvntsig                    Marco's Pita
# 4836  N7luSQX9HJIYJzIdqzIEng           Vickery's Bar & Grill
# 4837  P6VbBg5uNhAaANcpwm2cVQ           Moe's Southwest Grill
# 4838  OF1RGkYOeT2xxoi_Xnec7w                Emeril's Atlanta
# 4839  uXdQkuEtvLAzfc3MsO-sTQ            Mama's Cocina Latina
#
#                                                 address     city state  \
# 0                                  3393 Peachtree Rd NE  Atlanta    GA
# 1                                    3215 Roswell Rd NE  Atlanta    GA
# ...

# %%
import sqlite3
conn = sqlite3.connect('db.sqlite')

# %%
df1.to_sql('yelp_atl_restaurants', conn, if_exists='replace', index=False)

# %%
pd.read_sql('select * from yelp_atl_restaurants', conn)
# Out:
#                  business_id                            name  \
# 0     z8-_6l5EhX5NuPfWzJYQMA                     Great Wraps
# 1     Q2vefh0tGhtCGQDK1FI7cw                   Piece of Cake
# 2     TbZDLpBOl-EbO2LfMySrEg          First China Restaurant
# 3     bP6goJODwRnM3AVy45Kn9w  Papi's Cuban & Caribbean Grill
# 4     yCeENvVAGQQ0PeeWU0Pl2g           Nature's Table Bistro
# ...                      ...                             ...
# 4835  fyBLsgCl04kzDyDvvntsig                    Marco's Pita
# 4836  N7luSQX9HJIYJzIdqzIEng           Vickery's Bar & Grill
# 4837  P6VbBg5uNhAaANcpwm2cVQ           Moe's Southwest Grill
# 4838  OF1RGkYOeT2xxoi_Xnec7w                Emeril's Atlanta
# 4839  uXdQkuEtvLAzfc3MsO-sTQ            Mama's Cocina Latina
#
#                                                 address     city state  \
# 0                                  3393 Peachtree Rd NE  Atlanta    GA
# 1                                    3215 Roswell Rd NE  Atlanta    GA
# ...
