# %%
import json
import pandas as pd

# %%
data_file = open("yelp_academic_dataset_review.json", encoding='utf8')
data = []
for line in data_file:
    data.append(json.loads(line))
df = pd.DataFrame(data)
data_file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-8025507a9335> in <module>
# ----> 1 data_file = open("yelp_academic_dataset_review.json", encoding='utf8')
#       2 data = []
#       3 for line in data_file:
#       4     data.append(json.loads(line))
#       5 df = pd.DataFrame(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'yelp_academic_dataset_review.json'

# %%
df
# Out:
#                       review_id                 user_id  \
# 0        lWC-xP3rd6obsecCYsGZRg  ak0TdVmGKo4pwqdJSTLwWw
# 1        8bFej1QE5LXp4O05qjGqXA  YoVfDbnISlW0f7abNQACIg
# 2        NDhkzczKjLshODbqDoNLSg  eC5evKn1TWDyHCyQAwguUw
# 3        T5fAqjjFooT4V0OeZyuk1w  SFQ1jcnGguO0LYWnbbftAA
# 4        sjm_uUcQVxab_EeLCqsYLg  0kA0PAJ8QFMeveQWHFqz2A
# ...                         ...                     ...
# 8635398  PHnqMOU1pzHbnUMk3Cg2zA  6olZ0y9oW9azON61AhwxYg
# 8635399  dViF8gg9745CszpekNvp2g  EPYNZQFuSKqLi-on3U9dFg
# 8635400  7vNXRIClt-9rFzMXlrtMXA  tr13Jb83h2itjyXVwaO5eA
# 8635401  Ho57jz6U-JjrGHpGWIGLNg  HqdmRMpNvScFxjGAB40vgQ
# 8635402  YNyurWy1ZIYEy1vXI7azOg  HsT8bz3-SKMk7YidwLLM6Q
#
#                     business_id  stars  useful  funny  cool  \
# 0        buF9druCkbuXLX526sGELQ    4.0       3      1     1
# 1        RA4V8pr014UyUbDvI-LW2A    4.0       1      0     0
# 2        _sS2LBIGNT5NQb6PD1Vtjw    5.0       0      0     0
# ...

# %%
df.isnull().sum()
# Out:
# review_id      0
# user_id        0
# business_id    0
# stars          0
# useful         0
# funny          0
# cool           0
# text           0
# date           0
# dtype: int64

# %%
atl_restaurant_df=pd.read_csv("yelp_atl_restaurants_csv.csv")
atl_restaurant_df.head()
# Out:
#    Unnamed: 0             business_id                            name  \
# 0          62  z8-_6l5EhX5NuPfWzJYQMA                     Great Wraps
# 1          86  Q2vefh0tGhtCGQDK1FI7cw                   Piece of Cake
# 2         105  TbZDLpBOl-EbO2LfMySrEg          First China Restaurant
# 3         147  bP6goJODwRnM3AVy45Kn9w  Papi's Cuban & Caribbean Grill
# 4         165  xSLdQjPgMhBrNIEtUgdWUA                  Colossus Pizza
#
#                     address     city state  postal_code   latitude  longitude  \
# 0      3393 Peachtree Rd NE  Atlanta    GA        30326  33.846335 -84.363578
# 1        3215 Roswell Rd NE  Atlanta    GA        30305  33.842875 -84.378539
# 2        5295 Buford Hwy NE  Atlanta    GA        30340  33.896641 -84.280918
# 3  216 Ponce De Leon Ave NE  Atlanta    GA        30308  33.772758 -84.380375
# 4       4369 Hugh Howell Rd   Tucker    GA        30084  33.850775 -84.209299
#
#    stars  review_count  is_open  \
# 0    3.0            11        1
# ...

# %%
atl_restaurant_review_df=pd.merge(atl_restaurant_df,df, on="business_id", how ="left")
atl_restaurant_review_df
# Out:
#         Unnamed: 0             business_id                  name  \
# 0               62  z8-_6l5EhX5NuPfWzJYQMA           Great Wraps
# 1               62  z8-_6l5EhX5NuPfWzJYQMA           Great Wraps
# 2               62  z8-_6l5EhX5NuPfWzJYQMA           Great Wraps
# 3               62  z8-_6l5EhX5NuPfWzJYQMA           Great Wraps
# 4               62  z8-_6l5EhX5NuPfWzJYQMA           Great Wraps
# ...            ...                     ...                   ...
# 477664      160575  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina
# 477665      160575  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina
# 477666      160575  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina
# 477667      160575  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina
# 477668      160575  uXdQkuEtvLAzfc3MsO-sTQ  Mama's Cocina Latina
#
#                      address     city state  postal_code   latitude  \
# 0       3393 Peachtree Rd NE  Atlanta    GA        30326  33.846335
# ...

# %%
atl_restaurant_review_df.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a79322c70b4> in <module>
# ----> 1 atl_restaurant_review_df.head(2)
#
# NameError: name 'atl_restaurant_review_df' is not defined

# %%
atl_restaurant_review_df.isnull().sum()
# Out:
# Unnamed: 0          0
# business_id         0
# name                0
# address           384
# city                0
# state               0
# postal_code         0
# latitude            0
# longitude           0
# stars_x             0
# review_count        0
# is_open             0
# attributes        223
# categories          0
# hours           12296
# review_id           0
# user_id             0
# stars_y             0
# useful              0
# funny               0
# cool                0
# text                0
# date                0
# dtype: int64

# %%
atl_restaurant_review_df.describe()
# Out:
#           Unnamed: 0    postal_code       latitude      longitude  \
# count  477669.000000  477669.000000  477669.000000  477669.000000
# mean    80452.230949   30293.197758      33.810844     -84.348139
# std     45285.219516      80.658078       0.051241       0.039109
# min        62.000000   30002.000000      33.639048     -84.457466
# 25%     44673.000000   30307.000000      33.772263     -84.379998
# 50%     79200.000000   30309.000000      33.788608     -84.362511
# 75%    119517.000000   30326.000000      33.846838     -84.326684
# max    160575.000000   30360.000000      33.949866     -84.200206
#
#              stars_x   review_count        is_open        stars_y  \
# count  477669.000000  477669.000000  477669.000000  477669.000000
# mean        3.747752     551.748449       0.781074       3.744888
# std         0.541582     674.407010       0.413519       1.341652
# min         1.000000       5.000000       0.000000       1.000000
# ...

# %%
atl_restaurant_review_df.to_json("yelp_atl_restaurant_reviews_json.json")

# %%
atl_restaurant_review_df.to_csv("yelp_atl_restaurant_reviews_csv.csv")
